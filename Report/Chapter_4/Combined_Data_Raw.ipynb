# %%
from Data_DoE_GenmAb_Ambic import *
from Data_DoE_GenmAb_CDOptiCHO import *

Glucose = pd.concat([Glucose_Amb,Glucose_CD],axis=0).reset_index(drop=True)
Glutamine = pd.concat([Glutamine_Amb,Glutamine_CD],axis=0).reset_index(drop=True)
Lactate = pd.concat([Lactate_Amb,Lactate_CD],axis=0).reset_index(drop=True)
Ammonia = pd.concat([Ammonia_Amb,Ammonia_CD],axis=0).reset_index(drop=True)
TCD = pd.concat([TCD_Amb,TCD_CD],axis=0).reset_index(drop=True)
VCD = pd.concat([VCD_Amb,VCD_CD],axis=0).reset_index(drop=True)
IgG = pd.concat([IgG_Amb,IgG_CD],axis=0).reset_index(drop=True)

# %%
myFeatures = pd.concat([Glucose,Glutamine,Lactate,Ammonia,TCD,VCD,IgG],axis=1).astype(float)
myOutputs = pd.concat([Glycan_Amb,Glycan_CD],axis=0).astype(float)

# %%
#myFeatures

# %%
myOutputs
# Out:
#       A1   FA1     A2    FA2  A2G1  FA2G1  FA2G1'  A2G2  FA2G2
# 0   1.50  0.88  13.70  43.87  9.61  16.41    6.20  1.94   2.62
# 1   1.36  0.86  12.03  45.94  7.79  18.48    7.06  1.40   3.13
# 2   1.30  1.04   9.79  51.76  6.34  17.61    6.54  1.18   2.54
# 3   1.25  1.06   9.37  50.96  5.65  18.11    7.01  1.18   3.08
# 4   2.00  1.43  13.97  52.00  9.78  10.24    4.25  2.31   1.45
# 5   1.86  1.51  12.27  53.92  8.49  11.76    4.72  1.66   1.66
# 6   1.77  1.56  10.01  58.43  7.34  11.70    4.65  1.35   1.58
# 7   1.72  1.64   9.74  57.91  7.62  11.74    4.73  1.46   1.71
# 0   0.00  3.31   5.02  75.25  5.74   6.61    2.90  0.00   0.79
# 1   0.00  2.44   5.50  72.88  4.17   9.82    4.11  0.00   1.08
# 2   0.00  2.63   5.22  73.79  4.01   9.42    4.02  0.00   0.91
# 3   0.00  3.04   6.23  71.57  6.55   8.17    3.55  0.00   0.88
# 4   0.00  2.13   5.24  73.86  3.32  10.83    4.62  0.00   0.00
# 5   0.00  2.94   5.25  77.34  4.98   6.49    3.00  0.00   0.00
# 6   0.00  2.89   6.43  72.87  7.01   7.49    3.31  0.00   0.00
# 7   0.00  1.83   6.95  72.95  3.62  10.23    4.42  0.00   0.00
# 8   0.59  1.42   4.15  68.65  2.24  14.61    5.71  0.64   1.69
# 9   1.10  1.78   7.22  71.86  2.77   9.55    4.13  0.20   0.93
# 10  1.24  1.84   5.71  68.19  3.48  12.71    5.07  0.24   1.29
# 11  1.29  2.25   5.33  70.57  3.47  11.11    4.60  0.20   1.18
# 12  1.66  2.41   6.80  70.90  4.86   8.48    3.63  0.13   0.84
# 13  1.85  2.77   6.58  68.30  6.09   8.81    3.72  0.73   0.89
# 14  1.60  2.89   5.16  72.23  5.34   7.88    3.32  0.55   0.86
# 15  1.62  3.01   5.25  73.10  5.06   7.31    3.21  0.58   0.86
