# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from pandas.plotting import table

# %%
from Data_DoE_GenmAb_Ambic import *
from Data_DoE_GenmAb_CDOptiCHO import *

# %%
fig, ax = plt.subplots(figsize=(6, 4))
ax.set_frame_on(False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis
tabla = table(ax,Glucose_CD.head().round(2), loc='center', colWidths=[0.12]*len(Glucose_CD.head().columns))
tabla.auto_set_font_size(False) # Activate set fontsize manually
tabla.set_fontsize(12) # if ++fontsize is necessary ++colWidths
tabla.scale(2, 2)  # where df is your data frame
plt.title('Glucose Data',fontsize='x-large');
plt.savefig('GlucoseTable.png', transparent=True)
